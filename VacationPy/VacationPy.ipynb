# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from itertools import tee

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_data_path = "../output_data/city_weather.csv"

city_weather_data = pd.read_csv(city_data_path).drop(columns=['Unnamed: 0'])

city_weather_data.head()
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Kapaa  22.08 -159.32     78.80        78          40        9.17
# 1          Qaanaaq  77.48  -69.36     30.81        93          89        2.86
# 2        Esperance -33.87  121.90     55.17        86          94        6.17
# 3  Port Hawkesbury  45.62  -61.35     50.00        76          90        6.93
# 4            Korla  41.76   86.15     76.98        18           0        1.14
#
#   Country        Date
# 0      US  1591037288
# 1      GL  1591037288
# 2      AU  1591037288
# 3      CA  1591037288
# 4      CN  1591037288

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = city_weather_data[["Lat", "Lng"]].astype(float)

# Convert Humidity to float and store
# HINT: be sure to handle NaN values
humidity = city_weather_data["Humidity"].astype(float)

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure(center = (-2.77, -42.03), zoom_level = 2)

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_cities_df = city_weather_data.loc[(city_weather_data["Max Temp"]<90) & (city_weather_data["Max Temp"]>70)
                                       & (city_weather_data["Wind Speed"]<10) & (city_weather_data["Cloudiness"]<20)
                                       & (city_weather_data['Humidity']<80)]
ideal_cities_df.reset_index(inplace = False)
ideal_cities_df = ideal_cities_df.dropna()

ideal_cities_df.reset_index(drop = True)
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                     Korla  41.76   86.15     76.98        18           0
# 1                     Buala  -8.14  159.59     81.32        77           3
# 2       Santa María del Oro  25.93 -105.37     82.36        18           0
# 3             São Francisco -15.95  -44.86     80.08        44           0
# 4                   Humaitá  -7.51  -63.02     87.73        60          15
# 5                Esmeraldas -19.76  -44.31     75.20        41           0
# 6                 Manokwari  -0.87  134.08     79.83        78           3
# 7           Arraial do Cabo -22.97  -42.03     86.00        37           0
# 8                     Avera  33.19  -82.53     82.40        44           1
# 9                     Khāsh  28.22   61.22     78.31        17           0
# 10        São João da Barra -21.64  -41.05     82.40        42           4
# 11         La Roche-sur-Yon  46.67   -1.43     78.80        31           0
# 12                     Hilo  19.73 -155.09     78.80        74           1
# 13                 Florence  43.77   11.25     77.00        38           0
# 14  Gizo Government Station  -8.10  156.84     82.33        73           5
# 15                  Redding  40.59 -122.39     80.01        47           1
# 16                   Avarua -21.21 -159.78     75.20        69           9
# 17                  Sarakhs  36.54   61.16     86.40        12           0
# 18                   Milton  34.13  -84.30     81.00        59           0
# 19               Donji grad  45.81   15.98     71.60        46          12
# 20                    Umluj  25.02   37.27     80.42        55           0
# 21                    Ukiah  39.15 -123.21     75.99        49           1
# 22                 Morehead  37.27  -87.18     78.01        33           1
# 23             Porto Walter  -8.27  -72.74     89.73        50           4
# 24        Steamboat Springs  40.48 -106.83     77.00        29           1
# 25                   Abaeté -19.16  -45.45     74.07        57           6
# 26                 Lorengau  -2.02  147.27     81.09        73           5
# 27          Tiznit Province  29.58   -9.50     71.73        56           0
# 28                   Assiut  27.18   31.18     89.60        27           0
# 29                   Cortez  37.35 -108.59     82.40        28           1
# 30                 Araruama -22.87  -42.34     86.00        40           0
# 31                    Mahon  39.89    4.27     71.60        68           0
#
#     Wind Speed Country        Date
# 0         1.14      CN  1591037288
# 1         5.57      SB  1591037289
# 2         3.80      MX  1591037290
# 3         0.76      BR  1591037215
# 4         3.56      BR  1591037295
# 5         5.82      BR  1591037298
# 6         3.38      ID  1591037300
# 7         3.36      BR  1591037300
# 8         8.59      US  1591037301
# 9         3.62      IR  1591037302
# 10        9.17      BR  1591037303
# 11        9.17      FR  1591037303
# 12        3.36      US  1591037305
# 13        8.05      IT  1591037306
# 14        2.42      SB  1591037307
# 15        3.36      US  1591037314
# 16        6.93      CK  1591037316
# 17        6.17      IR  1591037316
# 18        1.01      US  1591037318
# 19        4.70      HR  1591037319
# 20        6.22      SA  1591037320
# 21        5.82      US  1591037323
# 22        5.82      US  1591037323
# 23        2.51      BR  1591037323
# 24        4.70      US  1591037324
# 25        3.69      BR  1591037326
# 26        2.21      PG  1591037337
# 27        7.40      MA  1591037338
# 28        6.93      EG  1591037338
# 29        6.93      US  1591037182
# 30        4.54      BR  1591037344
# 31        8.05      ES  1591037349

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_cities_df.reset_index(drop = True)

hotel_df['Hotel Name'] = ""

hotel_df
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                     Korla  41.76   86.15     76.98        18           0
# 1                     Buala  -8.14  159.59     81.32        77           3
# 2       Santa María del Oro  25.93 -105.37     82.36        18           0
# 3             São Francisco -15.95  -44.86     80.08        44           0
# 4                   Humaitá  -7.51  -63.02     87.73        60          15
# 5                Esmeraldas -19.76  -44.31     75.20        41           0
# 6                 Manokwari  -0.87  134.08     79.83        78           3
# 7           Arraial do Cabo -22.97  -42.03     86.00        37           0
# 8                     Avera  33.19  -82.53     82.40        44           1
# 9                     Khāsh  28.22   61.22     78.31        17           0
# 10        São João da Barra -21.64  -41.05     82.40        42           4
# 11         La Roche-sur-Yon  46.67   -1.43     78.80        31           0
# 12                     Hilo  19.73 -155.09     78.80        74           1
# 13                 Florence  43.77   11.25     77.00        38           0
# 14  Gizo Government Station  -8.10  156.84     82.33        73           5
# 15                  Redding  40.59 -122.39     80.01        47           1
# 16                   Avarua -21.21 -159.78     75.20        69           9
# 17                  Sarakhs  36.54   61.16     86.40        12           0
# 18                   Milton  34.13  -84.30     81.00        59           0
# 19               Donji grad  45.81   15.98     71.60        46          12
# 20                    Umluj  25.02   37.27     80.42        55           0
# 21                    Ukiah  39.15 -123.21     75.99        49           1
# 22                 Morehead  37.27  -87.18     78.01        33           1
# 23             Porto Walter  -8.27  -72.74     89.73        50           4
# 24        Steamboat Springs  40.48 -106.83     77.00        29           1
# 25                   Abaeté -19.16  -45.45     74.07        57           6
# 26                 Lorengau  -2.02  147.27     81.09        73           5
# 27          Tiznit Province  29.58   -9.50     71.73        56           0
# 28                   Assiut  27.18   31.18     89.60        27           0
# 29                   Cortez  37.35 -108.59     82.40        28           1
# 30                 Araruama -22.87  -42.34     86.00        40           0
# 31                    Mahon  39.89    4.27     71.60        68           0
#
#     Wind Speed Country        Date Hotel Name
# 0         1.14      CN  1591037288
# 1         5.57      SB  1591037289
# 2         3.80      MX  1591037290
# 3         0.76      BR  1591037215
# 4         3.56      BR  1591037295
# 5         5.82      BR  1591037298
# 6         3.38      ID  1591037300
# 7         3.36      BR  1591037300
# 8         8.59      US  1591037301
# 9         3.62      IR  1591037302
# 10        9.17      BR  1591037303
# 11        9.17      FR  1591037303
# 12        3.36      US  1591037305
# 13        8.05      IT  1591037306
# 14        2.42      SB  1591037307
# 15        3.36      US  1591037314
# 16        6.93      CK  1591037316
# 17        6.17      IR  1591037316
# 18        1.01      US  1591037318
# 19        4.70      HR  1591037319
# 20        6.22      SA  1591037320
# 21        5.82      US  1591037323
# 22        5.82      US  1591037323
# 23        2.51      BR  1591037323
# 24        4.70      US  1591037324
# 25        3.69      BR  1591037326
# 26        2.21      PG  1591037337
# 27        7.40      MA  1591037338
# 28        6.93      EG  1591037338
# 29        6.93      US  1591037182
# 30        4.54      BR  1591037344
# 31        8.05      ES  1591037349

# %%
# find the closest hotel of each type to coordinates
lat = row["Lat"]
lng = row["Lng"]

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": (lat,lng),
    "rankby": "distance",
    "type": "lodging",
    "key": g_key,
}
    
# use iterrows to iterate through pandas dataframe

for index, row in hotel_df.iterrows():
    
    
    # get city name from df
    city_name= hotel_df['City']

    # add keyword to params dict
#     params['keyword'] = city_name

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel to {city_name} is {results[0]['Hotel Name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['Hotel Name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# print(city_name)
# Out:
# Retrieving Results for Index 0: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 1: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 2: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 3: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 4: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 5: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 6: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 7: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 8: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 9: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 10: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 11: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 12: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 13: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 14: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 15: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 16: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 17: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 18: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 19: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 20: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 21: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 22: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 23: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 24: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 25: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 26: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 27: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 28: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 29: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 30: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 31: 0                       Korla
# 1                       Buala
# 2         Santa María del Oro
# 3               São Francisco
# 4                     Humaitá
# 5                  Esmeraldas
# 6                   Manokwari
# 7             Arraial do Cabo
# 8                       Avera
# 9                       Khāsh
# 10          São João da Barra
# 11           La Roche-sur-Yon
# 12                       Hilo
# 13                   Florence
# 14    Gizo Government Station
# 15                    Redding
# 16                     Avarua
# 17                    Sarakhs
# 18                     Milton
# 19                 Donji grad
# 20                      Umluj
# 21                      Ukiah
# 22                   Morehead
# 23               Porto Walter
# 24          Steamboat Springs
# 25                     Abaeté
# 26                   Lorengau
# 27            Tiznit Province
# 28                     Assiut
# 29                     Cortez
# 30                   Araruama
# 31                      Mahon
# Name: City, dtype: object.
# Missing field/result... skipping.
# ------------

# %%
print(results)
# Out:
# []

# %%
hotel_df
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                     Korla  41.76   86.15     76.98        18           0
# 1                     Buala  -8.14  159.59     81.32        77           3
# 2       Santa María del Oro  25.93 -105.37     82.36        18           0
# 3             São Francisco -15.95  -44.86     80.08        44           0
# 4                   Humaitá  -7.51  -63.02     87.73        60          15
# 5                Esmeraldas -19.76  -44.31     75.20        41           0
# 6                 Manokwari  -0.87  134.08     79.83        78           3
# 7           Arraial do Cabo -22.97  -42.03     86.00        37           0
# 8                     Avera  33.19  -82.53     82.40        44           1
# 9                     Khāsh  28.22   61.22     78.31        17           0
# 10        São João da Barra -21.64  -41.05     82.40        42           4
# 11         La Roche-sur-Yon  46.67   -1.43     78.80        31           0
# 12                     Hilo  19.73 -155.09     78.80        74           1
# 13                 Florence  43.77   11.25     77.00        38           0
# 14  Gizo Government Station  -8.10  156.84     82.33        73           5
# 15                  Redding  40.59 -122.39     80.01        47           1
# 16                   Avarua -21.21 -159.78     75.20        69           9
# 17                  Sarakhs  36.54   61.16     86.40        12           0
# 18                   Milton  34.13  -84.30     81.00        59           0
# 19               Donji grad  45.81   15.98     71.60        46          12
# 20                    Umluj  25.02   37.27     80.42        55           0
# 21                    Ukiah  39.15 -123.21     75.99        49           1
# 22                 Morehead  37.27  -87.18     78.01        33           1
# 23             Porto Walter  -8.27  -72.74     89.73        50           4
# 24        Steamboat Springs  40.48 -106.83     77.00        29           1
# 25                   Abaeté -19.16  -45.45     74.07        57           6
# 26                 Lorengau  -2.02  147.27     81.09        73           5
# 27          Tiznit Province  29.58   -9.50     71.73        56           0
# 28                   Assiut  27.18   31.18     89.60        27           0
# 29                   Cortez  37.35 -108.59     82.40        28           1
# 30                 Araruama -22.87  -42.34     86.00        40           0
# 31                    Mahon  39.89    4.27     71.60        68           0
#
#     Wind Speed Country        Date Hotel Name
# 0         1.14      CN  1591037288
# 1         5.57      SB  1591037289
# 2         3.80      MX  1591037290
# 3         0.76      BR  1591037215
# 4         3.56      BR  1591037295
# 5         5.82      BR  1591037298
# 6         3.38      ID  1591037300
# 7         3.36      BR  1591037300
# 8         8.59      US  1591037301
# 9         3.62      IR  1591037302
# 10        9.17      BR  1591037303
# 11        9.17      FR  1591037303
# 12        3.36      US  1591037305
# 13        8.05      IT  1591037306
# 14        2.42      SB  1591037307
# 15        3.36      US  1591037314
# 16        6.93      CK  1591037316
# 17        6.17      IR  1591037316
# 18        1.01      US  1591037318
# 19        4.70      HR  1591037319
# 20        6.22      SA  1591037320
# 21        5.82      US  1591037323
# 22        5.82      US  1591037323
# 23        2.51      BR  1591037323
# 24        4.70      US  1591037324
# 25        3.69      BR  1591037326
# 26        2.21      PG  1591037337
# 27        7.40      MA  1591037338
# 28        6.93      EG  1591037338
# 29        6.93      US  1591037182
# 30        4.54      BR  1591037344
# 31        8.05      ES  1591037349

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
