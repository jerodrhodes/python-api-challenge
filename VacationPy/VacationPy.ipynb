# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from itertools import tee
# !jupyter nbextension enable --py gmaps

# Import API key
from api_keys import g_key
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_data_path = "../output_data/city_weather.csv"

city_weather_data = pd.read_csv(city_data_path).drop(columns=['Unnamed: 0'])

city_weather_data.head()
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Kapaa  22.08 -159.32     78.80        78          40        9.17
# 1          Qaanaaq  77.48  -69.36     30.81        93          89        2.86
# 2        Esperance -33.87  121.90     55.17        86          94        6.17
# 3  Port Hawkesbury  45.62  -61.35     50.00        76          90        6.93
# 4            Korla  41.76   86.15     76.98        18           0        1.14
#
#   Country        Date
# 0      US  1591037288
# 1      GL  1591037288
# 2      AU  1591037288
# 3      CA  1591037288
# 4      CN  1591037288

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = city_weather_data[["Lat", "Lng"]].astype(float)

# Convert Humidity to float and store
# HINT: be sure to handle NaN values
humidity = city_weather_data["Humidity"].astype(float)

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure(center = (-2.77, -42.03), zoom_level = 2)

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_cities_df = city_weather_data.loc[(city_weather_data["Max Temp"]<90) & (city_weather_data["Max Temp"]>70)
                                       & (city_weather_data["Wind Speed"]<10) & (city_weather_data["Cloudiness"]<20)
                                       & (city_weather_data['Humidity']<80)]
ideal_cities_df.reset_index(inplace = False)
ideal_cities_df = ideal_cities_df.dropna()

ideal_cities_df.reset_index(drop = True)
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                     Korla  41.76   86.15     76.98        18           0
# 1                     Buala  -8.14  159.59     81.32        77           3
# 2       Santa María del Oro  25.93 -105.37     82.36        18           0
# 3             São Francisco -15.95  -44.86     80.08        44           0
# 4                   Humaitá  -7.51  -63.02     87.73        60          15
# 5                Esmeraldas -19.76  -44.31     75.20        41           0
# 6                 Manokwari  -0.87  134.08     79.83        78           3
# 7           Arraial do Cabo -22.97  -42.03     86.00        37           0
# 8                     Avera  33.19  -82.53     82.40        44           1
# 9                     Khāsh  28.22   61.22     78.31        17           0
# 10        São João da Barra -21.64  -41.05     82.40        42           4
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_cities_df.reset_index(drop = True)

hotel_df['Hotel Name'] = ""

hotel_df
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                     Korla  41.76   86.15     76.98        18           0
# 1                     Buala  -8.14  159.59     81.32        77           3
# 2       Santa María del Oro  25.93 -105.37     82.36        18           0
# 3             São Francisco -15.95  -44.86     80.08        44           0
# 4                   Humaitá  -7.51  -63.02     87.73        60          15
# 5                Esmeraldas -19.76  -44.31     75.20        41           0
# 6                 Manokwari  -0.87  134.08     79.83        78           3
# 7           Arraial do Cabo -22.97  -42.03     86.00        37           0
# 8                     Avera  33.19  -82.53     82.40        44           1
# 9                     Khāsh  28.22   61.22     78.31        17           0
# 10        São João da Barra -21.64  -41.05     82.40        42           4
# ...

# %%
# find the closest hotel of each type to coordinates


base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    
# use iterrows to iterate through pandas dataframe

for index, row in hotel_df.iterrows():
    #define variables for latitude and longitude
    lat = row["Lat"]
    lng = row["Lng"]
    
    params = {
    "location": f"{lat},{lng}",
    "rankby": "distance",
    "type": "lodging",
    "key": g_key,
    }
    
    
    # get city name from df
    city_name= row['City']

    # add keyword to params dict
#     params['keyword'] = city_name

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel to {city_name} is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# print(city_name)
# Out:
# Retrieving Results for Index 0: Korla.
# Closest hotel to Korla is 昭君客栈.
# ------------
# Retrieving Results for Index 1: Buala.
# Closest hotel to Buala is Maringe Lagoon Lodge.
# ------------
# Retrieving Results for Index 2: Santa María del Oro.
# Closest hotel to Santa María del Oro is Hotel Palacio Del Sol.
# ------------
# Retrieving Results for Index 3: São Francisco.
# Closest hotel to São Francisco is Hotel Pallas.
# ------------
# Retrieving Results for Index 4: Humaitá.
# Closest hotel to Humaitá is Hotel Amazônia.
# ------------
# Retrieving Results for Index 5: Esmeraldas.
# Closest hotel to Esmeraldas is Hotel Fazenda Lagoa Azul.
# ------------
# Retrieving Results for Index 6: Manokwari.
# Closest hotel to Manokwari is LAUNDRY "MIQUME".
# ------------
# Retrieving Results for Index 7: Arraial do Cabo.
# Closest hotel to Arraial do Cabo is Kitchenette Elaine Arraial do Cabo.
# ------------
# Retrieving Results for Index 8: Avera.
# Missing field/result... skipping.
# ...

# %%
hotel_df
# Out:
#                        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                     Korla  41.76   86.15     76.98        18           0
# 1                     Buala  -8.14  159.59     81.32        77           3
# 2       Santa María del Oro  25.93 -105.37     82.36        18           0
# 3             São Francisco -15.95  -44.86     80.08        44           0
# 4                   Humaitá  -7.51  -63.02     87.73        60          15
# 5                Esmeraldas -19.76  -44.31     75.20        41           0
# 6                 Manokwari  -0.87  134.08     79.83        78           3
# 7           Arraial do Cabo -22.97  -42.03     86.00        37           0
# 8                     Avera  33.19  -82.53     82.40        44           1
# 9                     Khāsh  28.22   61.22     78.31        17           0
# 10        São João da Barra -21.64  -41.05     82.40        42           4
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
hotel_layer = gmaps.marker_layer(locations, info_box_content= hotel_info)

# Display figure
fig.add_layer(hotel_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
